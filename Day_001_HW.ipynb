# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # HW1

# %%
#1.因為可以用來預測心臟疾病，及早進行治療，避免不可逆的傷害。
#2.提供者為a. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D. (匈牙利心臟病研究所)
#         b. University Hospital, Zurich, Switzerland: William Steinbrunn, M.D. (瑞士蘇黎世大學醫院)
#         c. University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D. (瑞士巴賽爾大學醫院)
#         d. V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.(克里夫蘭診所,為世界著名醫療機構)
#3.資料型態:整數
#4.評估14種標籤中哪幾種，對於預測心臟疾病最有關?再將預測的結果，跟真實的data做比較，進一步修正模型。

# %% [markdown]
# # HW2

# %%
#1.提升業績and我的假設:a.讓空車的時間最小化
#                     b.車主花最少路程就可以順利載到客人。
#2.空車時間:每次載完客到下一次載客的時間
#  路程:用google地圖判斷，車主確認載客時跟乘客當下的距離。
#3.資料型態:時間、浮點數(距離)
#4.a.先進行「將空車時間最小化的步驟」，和完全沒優化相比，檢視是否有效提升業績?
#  b.進行「車主花最少路程就可以順利載到客人」，和完全沒優化相比，檢視是否有效提升業績?
#  c.以上兩點如有不符合預期，先個別分析模型可能有誤的地方，個別做優化。
#  d.將兩點假設綜合在一起，和只有採納其中一點假設後優化的模型相比，檢視是否有效提升業績?

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE=sum(pow(y-yp,2))/len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 219.500
# The Mean absolute error is 12.058
